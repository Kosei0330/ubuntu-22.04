# %%
###   カーネルの選択、のところで、Python 3.10.13 を選択する。

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

x,y = np.loadtxt("3_2.txt" , unpack=True)

plt.figure(figsize=(6,6))   ### 正方形に出力する
plt.xlim(-2,2)   ### 範囲の変更
plt.ylim(-2,2)
plt.plot(x,y, label="symplectic solution")

plt.legend(loc="upper right")   ### 凡例を右上に出す
